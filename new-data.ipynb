# %%
import numpy as np
import pandas as pd
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import torch.optim as optim
# from torch.utils.data import Dataset, DataLoader

# %%
data = pd.read_excel('./data/new.xlsx', header=[0,1])
# no warning 
df = data.drop('这些变量不用管', axis=1, level=0)
df.head()
# Out:
#   分组变量      结局变量          影响因素                                               \
#   淋巴清扫 总体生存时间（月） 生存状态 feature1 feature2 feature3 feature4 feature5 feature6
# 0    0      34.0    1        1       46        0        0        0     4.60
# 1    1      11.0    0        2       57        0        1        1     4.10
# 2    1       6.0    1        1       54        0        0        1     2.66
# 3    1       6.0    1        1       58        0        0        1     6.03
# 4    1       3.0    0        1       54        0        0        2    10.88
#
#             ...                                                             \
#   feature7  ... feature9 feature10 feature11 feature12 feature13 feature14
# 0     1.12  ...     4.69     16.50    558.60     111.0      61.3      43.2
# 1     0.20  ...     3.93     12.73   1000.00     666.0      22.4      24.4
# 2     0.67  ...     2.67      8.12    779.20     204.0     179.9      30.3
# 3     1.15  ...     3.04      1.66   1000.00      51.0      13.6      37.2
# 4     1.74  ...     4.03     15.00     28.22      22.0       7.7      38.3
#
#
#   feature15 feature16 feature17 feature18
# 0      14.2         2       8.0         1
# 1      15.9         2       6.5         1
# 2      15.0         2       5.0         1
# 3      14.0         2       8.0         1
# 4      13.2         2       6.5         1
#
# [5 rows x 21 columns]

# %%
# n = 10
# draws = np.random.randint(0, 2, n)
# steps = np.where(draws>0, 1, -1)
# walk = steps.cumsum()
# walk
